# %%
import pandas as pd

# %%
df=pd.read_csv('/home/miguel/msc-tesis/ssl_satellital/exp_34/logs/exp_34_train_v2.csv')
df
# Out:
#     kfold  iteracion arquitectura  val_loss  val_accu  test_loss  test_accu  \
# 0       0          0    ResNet152  0.484925  0.872296   0.468022   0.873410
# 1       0          0  InceptionV3  0.805570  0.798346   0.790335   0.805185
# 2       0          0  InceptionV4  1.093230  0.838900   0.891647   0.837468
# 3       0          0     co-train       NaN       NaN        NaN   0.882634
# 4       0          1    ResNet152  0.445752  0.883747   0.438161   0.884224
# 5       0          1  InceptionV3  0.666593  0.818066   0.665499   0.823632
# 6       0          1  InceptionV4  0.854494  0.838422   0.725134   0.846533
# 7       0          1     co-train       NaN       NaN        NaN   0.887564
# 8       0          2    ResNet152  0.486071  0.884701   0.512018   0.875954
# 9       0          2  InceptionV3  0.582001  0.838740   0.574174   0.838740
# 10      0          2  InceptionV4  0.743189  0.850191   0.702019   0.849237
# ...
