# %%
import pandas as pd

# %%
df = pd.read_csv('/home/miguel/msc-tesis/ssl_gleasson/exp_37/results/exp_79/hardvard/logs/exp_79_train.csv')
df
# Out:
#    kfold  iteracion arquitectura  val_loss  val_accu  test1_loss  test1_accu  \
# 0      0          0     ResNet50  0.476063  0.782197    0.569296    0.748843
# 1      0          0     Xception  0.458773  0.783144    0.554874    0.744792
# 2      0          0  DenseNet169  0.466694  0.760417    0.527841    0.741898
# 3      0          0  InceptionV4  0.473043  0.770833    0.576259    0.733507
# 4      0          0  DenseNet121  0.464017  0.782197    0.521807    0.746238
#
#    test1_precision  test1_recall  test1_f1score  test2_loss  test2_accu  \
# 0         0.748492      0.748843       0.748283    0.742129    0.691551
# 1         0.744753      0.744792       0.743672    0.622044    0.710069
# 2         0.741585      0.741898       0.741652    0.636004    0.681134
# 3         0.733539      0.733507       0.732102    0.626364    0.701099
# 4         0.751275      0.746238       0.742281    0.561094    0.733507
#
#    test2_precision  test2_recall  test2_f1score
# ...

# %%
df = pd.read_csv('/home/miguel/msc-tesis/ssl_gleasson/exp_37/results/exp_80/hardvard/logs/exp_80_train.csv')
df#.sort_values('val_accu', ascending=False)
# Out:
#     kfold  iteracion arquitectura  val_loss  val_accu  test1_loss  test1_accu  \
# 0       0          0     ResNet50  0.477091  0.772727    0.564548    0.747685
# 1       0          0     Xception  0.458741  0.783144    0.550744    0.743345
# 2       0          0  DenseNet169  0.470676  0.757576    0.531072    0.737268
# 3       0          0  InceptionV4  0.469723  0.777462    0.567774    0.734086
# 4       0          0  DenseNet121  0.461629  0.784091    0.543162    0.739005
# 5       0          0    co-train1       NaN       NaN         NaN    0.752604
# 6       0          0    co-train2       NaN       NaN         NaN    0.727141
# 7       0          1     ResNet50  0.479306  0.764205    0.558845    0.739583
# 8       0          1     Xception  0.472290  0.780303    0.586626    0.736111
# 9       0          1  DenseNet169  0.456292  0.788826    0.530448    0.742477
# 10      0          1  InceptionV4  0.492041  0.771780    0.596987    0.737268
# ...

# %%
# df_dict = {n: df.iloc[n:n+4, :] 
#            for n in range(0, len(df), 4)}
# df_dict.keys()

# %%
df = pd.read_csv('/home/miguel/msc-tesis/ssl_gleasson/exp_37/results/exp_82/hardvard/logs/exp_82_train.csv')
df
# Out:
#    kfold  iteracion arquitectura  val_loss  val_accu  test1_loss  test1_accu  \
# 0      0          0     ResNet50  0.480353  0.776515    0.566342    0.744213
# 1      0          0     Xception  0.461361  0.780303    0.552795    0.744213
# 2      0          0  DenseNet169  0.470059  0.759470    0.532919    0.734954
# 3      0          0  InceptionV4  0.472154  0.776515    0.573072    0.735243
# 4      0          0  DenseNet121  0.464059  0.775568    0.535434    0.743924
# 5      0          0    co-train1       NaN       NaN         NaN    0.755208
# 6      0          0    co-train2       NaN       NaN         NaN    0.710069
# 7      0          1     ResNet50  0.500126  0.789773    0.643443    0.749132
#
#    test1_precision  test1_recall  test1_f1score  test2_loss  test2_accu  \
# 0         0.743838      0.744213       0.743815    0.750198    0.687500
# 1         0.744308      0.744213       0.742950    0.617938    0.711806
# ...

# %%
df = pd.read_csv('/home/miguel/msc-tesis/ssl_gleasson/exp_37/results/exp_83/hardvard/logs/exp_83_train.csv')
df
# Out:
#     kfold  iteracion arquitectura  val_loss  val_accu  test1_loss  test1_accu  \
# 0       0          0     ResNet50  0.488956  0.767992    0.531885    0.740451
# 1       0          0     Xception  0.522117  0.728220    0.553713    0.717882
# 2       0          0  DenseNet169  0.476327  0.772727    0.525075    0.737268
# 3       0          0  InceptionV4  0.473706  0.781250    0.532113    0.731192
# 4       0          0  DenseNet121  0.519293  0.729167    0.555681    0.706308
# 5       0          0    co-train1       NaN       NaN         NaN    0.757812
# 6       0          0    co-train2       NaN       NaN         NaN    0.678530
# 7       0          1     ResNet50  0.490022  0.768939    0.590548    0.734086
# 8       0          1     Xception  0.473716  0.758523    0.545922    0.726852
# 9       0          1  DenseNet169  0.472273  0.764205    0.517564    0.742766
# 10      0          1  InceptionV4  0.464349  0.776515    0.588909    0.740741
# ...
